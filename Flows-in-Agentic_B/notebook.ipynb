# %% [markdown]
# it's crucial to balance structured workflows with AI-driven autonomy.
#
# **Flows** help us do that.
#
# Essentially, Flows enable developers to design workflows that seamlessly integrate deterministic processes with AI's adaptive reasoning.
#
# By structuring interactions between traditional code and LLMs, Flows ensure that while AI agents have the *autonomy to interpret* and *respond to complex inputs*, they do so within a controlled and predictable framework.
#
# In essence, Flows provide the infrastructure to harness the strengths of both traditional software logic and AI autonomy, creating cohesive systems that are both reliable and intelligent.

# %% [markdown]
# ## 1) The @start decorator
#
# marks the first method that begins execution in a Flow. This function runs automatically when the Flow starts.

# %%
from crewai.flow.flow import Flow, start

class SimpleFlow(Flow):

    @start()
    def initialize(self):
        print("Flow started")

flow = SimpleFlow()
await flow.kickoff_async()
# Out:
# ╭─────────────────────────────────────────────── 🌊 Flow Execution ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Starting Flow Execution                                                                                        │
# │  Name: SimpleFlow                                                                                               │
# │  ID: 988fc488-a45b-4ede-82c2-a1b40ed646e9                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ...

# %% [markdown]
# ## 2) Method
#
# *@listen* runs after another method completes

# %%
from crewai.flow.flow import Flow, listen, start

class SequentialFlow(Flow):

    @start()
    def first_task(self):
        print("Step 1: fetching data")
        return "data_fetched"

    @listen
    def second_task(self, result):
        print(f"Step 2: processing {result}")

flow = SequentialFlow()
await flow.kickoff_async()
# Out:
# ╭─────────────────────────────────────────────── 🌊 Flow Execution ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Starting Flow Execution                                                                                        │
# │  Name: SequentialFlow                                                                                           │
# │  ID: e5a76561-96e6-4a50-adbe-e4a89163e5e5                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ...

# %% [markdown]
# ## 3) The *or_()* function
#
# allows a task to execute when at least one of its dependencies is completed.

# %%
from crewai.flow.flow import Flow, listen, or_, start

class OrFlow(Flow):

    @start()
    def fetch_from_api(self):
        return "API data"

    @start
    def read_from_db(self):
        return "Database record"
    
    @listen(or_(fetch_from_api, read_from_db))
    def process_data(self, result):
        print(f"Processing: {result}") 

flow = OrFlow()
await flow.kickoff_async()
# Out:
# ╭─────────────────────────────────────────────── 🌊 Flow Execution ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Starting Flow Execution                                                                                        │
# │  Name: OrFlow                                                                                                   │
# │  ID: b96ddfd2-637d-4eb5-b64b-2986ff813a32                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ...

# %% [markdown]
# ## 4) The *and_()* function
#
# ensures that a task runs only after all dependencies have been completed.

# %%
from crewai.flow.flow import Flow, listen, start, and_

class AndFlow(Flow):

    @start()
    def step_one(self):
        print("Step 1: Collecting user input")
        return "User data"

    @start()
    def step_two(self):
        print("Step 2: Validating input")
        return "Validated data"

    @listen(and_(step_one, step_two))
    def final_step(self):
        print("All conditions met. Procedding with the final step.")

flow = AndFlow()
await flow.kickoff_async()
# Out:
# ╭─────────────────────────────────────────────── 🌊 Flow Execution ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Starting Flow Execution                                                                                        │
# │  Name: AndFlow                                                                                                  │
# │  ID: 2d9d6395-5ef5-494b-9291-5ae89d8f841f                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ...

# %% [markdown]
# ## 5) *@router* decorator directs execution based on conditional logic

# %%
import random 
from crewai.flow.flow import Flow, listen, start, router

class RouterFlow(Flow):

    @start()
    def classify_request(self):
        request_type = random.choice(["urgent", "normal"])
        print(f"Request classified as: {request_type}")
        return request_type

    @router(classify_request)
    def handle_request(self, classification):
        if classification == "urgent":
            return "handle_urgent"
        else:
            return "handle_normal"

    @listen("handle_urgent")
    def urgent_handler(self):
        print("Handling urgent request")

    @listen("handle_normal")
    def normal_handler(self):
        print("Handling normal request")

flow = RouterFlow()
await flow.kickoff_async()
# Out:
# ╭─────────────────────────────────────────────── 🌊 Flow Execution ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Starting Flow Execution                                                                                        │
# │  Name: RouterFlow                                                                                               │
# │  ID: dd095020-2a23-4c5d-b246-3864a2398b31                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ...

# %% [markdown]
# ## 6) Each flow has a state dictionary *self.state* which persists values across steps.
#
# The state persists values across steps
# The state persists values betwen tasks, allowing dynamic updates

# %%
from crewai.flow.flow import Flow, listen, start

class StateFlow(Flow):

    @start()
    def initialize_state(self):
        self.state["count"] = 1
        print(f"Initial count: {self.state['count']}")

    @listen(initialize_state)
    def increment_count(self):
        self.state["count"] += 1
        print(f"Updated count: {self.state['count']}")

flow = StateFlow()
await flow.kickoff_async()
# Out:
# ╭─────────────────────────────────────────────── 🌊 Flow Execution ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Starting Flow Execution                                                                                        │
# │  Name: StateFlow                                                                                                │
# │  ID: 8eecae5f-db56-4200-8f91-a141493ce782                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ...

# %% [markdown]
# ## 7) By default, CrewAI Flows use an unstructured state dictionary (*self.state*).
#
# ### However, for better data validation, type safety, and maintainability, we can use structured state management with pydantic.
#
# Structured states define a fixed schema for storing and managing state values.

# %%
from crewai.flow.flow import Flow, listen, start
from pydantic import BaseModel

# Defining a structured state model
class CounterState(BaseModel):
    count: int = 0

class StructuredStateFlow(Flow[CounterState]):
# Flow uses CounterState as its state blueprint
    @start()
    def initialize_state(self):
        print(f"Initial count: {self.state.count}")
        self.state.count = 1

    @listen(initialize_state)
    def increment_count(self):
        self.state.count += 1
        print(f"Updated count: {self.state.count}")

flow = StructuredStateFlow()
await flow.kickoff_async()
# Out:
# ╭─────────────────────────────────────────────── 🌊 Flow Execution ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Starting Flow Execution                                                                                        │
# │  Name: StructuredStateFlow                                                                                      │
# │  ID: e58da15a-77af-4451-9fe4-e797be03fa86                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ...

# %% [markdown]
# | 	|Dictionary {}	| Pydantic Model |
# |---|---|---|
# |Access |	state["count"] | self.state.count |
# |Typo |	state["coutn"] → KeyError at runtime |	self.state.coutn → error immediately |
# |Type check	| No — anything goes |	Yes — count: int rejects "hello" |
# |Default values |	You set manually |	Defined in the class |
# |Autocomplete in editor |	NO	| YES |

# %% [markdown]
# In the above code:
#
# - The state is strictly defined using pydantic.
# - Type safety ensures that count is always an integer.
# - If an undefined attribute is accessed, CrewAI raises an error instead of silently allowing unexpected behavior.
#
# Now that we have covered task execution, flow control, and state management, we can move on to building complex multi-crew Flows.
#
# ----------
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ```mermaid
# graph TD
#     %% Nodes definition
#     A[Scrape Blog Post]:::scrape --> B[Select Platform]:::router
#     B -.->|Twitter| C[Twitter Draft]:::draft
#     B -.->|LinkedIn| D[Linkedin Draft]:::draft
#     C --> E[Save Plan]:::action
#     C --> F[Publish]:::action
#     D --> E
#     D --> F
#
#     %% Styling and Colors
#     classDef scrape fill:#F0706A,stroke:#333,stroke-width:1px,color:#fff;
#     classDef router fill:#352635,stroke:#333,stroke-width:1px,color:#fff;
#     classDef draft fill:#28282B,stroke:#333,stroke-width:1px,color:#fff;
#     classDef action fill:#28282B,stroke:#333,stroke-width:1px,color:#fff;
#
#     %% Custom link styling to match diagram arrows
#     linkStyle 1 stroke:#F0706A,stroke-width:1px,stroke-dasharray: 3;
#     linkStyle 2 stroke:#F0706A,stroke-width:1px,stroke-dasharray: 3;

# %% [markdown]
# ## Here’s how it works:
#
# - We provide a link to a blog/article.
# - We use Firecrawl to scrape the newsletter (with images) and save it as a markdown.
# - Since there are multiple agents, one agent has access to our existing social content to understand our writing style.
# - Next, since we publish content on LinkedIn and X, we built two routers in this agentic workflow. Based on a trigger, another agent gets executed to write a ready-to-publish draft.
# - Finally, we save the content plan as a structured JSON file.
#
# Let's look at the full end-to-end implementation below.

# %%
from crewai import LLM 
from dotenv import load_dotenv

load_dotenv()

llm = LLM(
    model="gemini/gemini-3.5-flash",
    temperature=0.6)

llm_local = LLM(
    model="ollama/qwen3.5:4b",
    base_url="http://localhost:11434"
)

# %% [markdown]
# ## Sample files
#
# Ensure that AI generated content follows a consistent writing style, asset folders contain the following files:
#
# - example_threads.txt : Contains examples of well structured Twitter threads
# - example_linkedin.txt : Contains samples of Linkedin posts with proper formatting, tone, and structure
#
# Agents (AI Workers)
# Tasks (What they do)
#
# - Draft Analyzer : Extracts key ideas, sections, and media from the blog post.
# - Twitter Thread Planner : Converts the blog content into an engaging Twitter thread.
# - LinkedIn Post Planner : Creates a well-structured LinkedIn post optimized for professional
#
# We create *config/* folder with 2 files-
#
# - planner_agents.yaml : Defines each agent's role, goal, and expertise
# - planner_tasks.yaml : Specifies what each agent is responsible for
